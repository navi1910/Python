# %%
import requests

# %%
key = '7645c564ea36454c8e4e03c788702956'

# %%
api_url =  f'https://api.weatherbit.io/v2.0/current?lat=35.7796&lon=-78.6382&key={key}&include=minutely'

# %%
response = requests.get(api_url)
data = response.json()

# %%
data
# Out:
# {'count': 1,
#  'data': [{'app_temp': 23.4,
#    'aqi': 42,
#    'city_name': 'Raleigh',
#    'clouds': 7,
#    'country_code': 'US',
#    'datetime': '2023-07-12:05',
#    'dewpt': 20.1,
#    'dhi': 0,
#    'dni': 0,
#    'elev_angle': -31.47,
#    'ghi': 0,
#    'gust': None,
#    'h_angle': -90,
#    'lat': 35.7796,
#    'lon': -78.6382,
#    'ob_time': '2023-07-12 05:40',
#    'pod': 'n',
#    'precip': 0,
#    'pres': 1004,
#    'rh': 85,
#    'slp': 1016.9,
#    'snow': 0,
#    'solar_rad': 0,
#    'sources': ['1327W'],
#    'state_code': 'NC',
#    'station': '1327W',
#    'sunrise': '10:07',
#    'sunset': '00:32',
#    'temp': 22.8,
#    'timezone': 'America/New_York',
#    'ts': 1689140400,
#    'uv': 0,
#    'vis': 14,
#    'weather': {'icon': 'c01n', 'description': 'Clear sky', 'code': 800},
#    'wind_cdir': 'N',
#    'wind_cdir_full': 'north',
#    'wind_dir': 0,
#    'wind_spd': 1}],
#  'minutely': [{'precip': 0,
#    'snow': 0,
#    'temp': 22.8,
#    'ts': 1689141720,
#    'timestamp_utc': '2023-07-12T06:02:00',
#    'timestamp_local': '2023-07-12T02:02:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 22.8,
#    'ts': 1689141780,
#    'timestamp_utc': '2023-07-12T06:03:00',
#    'timestamp_local': '2023-07-12T02:03:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 22.7,
#    'ts': 1689141840,
#    'timestamp_utc': '2023-07-12T06:04:00',
#    'timestamp_local': '2023-07-12T02:04:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 22.7,
#    'ts': 1689141900,
#    'timestamp_utc': '2023-07-12T06:05:00',
#    'timestamp_local': '2023-07-12T02:05:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 22.7,
#    'ts': 1689141960,
#    'timestamp_utc': '2023-07-12T06:06:00',
#    'timestamp_local': '2023-07-12T02:06:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 22.6,
#    'ts': 1689142020,
#    'timestamp_utc': '2023-07-12T06:07:00',
#    'timestamp_local': '2023-07-12T02:07:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 22.6,
#    'ts': 1689142080,
#    'timestamp_utc': '2023-07-12T06:08:00',
#    'timestamp_local': '2023-07-12T02:08:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 22.5,
#    'ts': 1689142140,
#    'timestamp_utc': '2023-07-12T06:09:00',
#    'timestamp_local': '2023-07-12T02:09:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 22.5,
#    'ts': 1689142200,
#    'timestamp_utc': '2023-07-12T06:10:00',
#    'timestamp_local': '2023-07-12T02:10:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 22.5,
#    'ts': 1689142260,
#    'timestamp_utc': '2023-07-12T06:11:00',
#    'timestamp_local': '2023-07-12T02:11:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 22.4,
#    'ts': 1689142320,
#    'timestamp_utc': '2023-07-12T06:12:00',
#    'timestamp_local': '2023-07-12T02:12:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 22.4,
#    'ts': 1689142380,
#    'timestamp_utc': '2023-07-12T06:13:00',
#    'timestamp_local': '2023-07-12T02:13:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 22.3,
#    'ts': 1689142440,
#    'timestamp_utc': '2023-07-12T06:14:00',
#    'timestamp_local': '2023-07-12T02:14:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 22.3,
#    'ts': 1689142500,
#    'timestamp_utc': '2023-07-12T06:15:00',
#    'timestamp_local': '2023-07-12T02:15:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 22.3,
#    'ts': 1689142560,
#    'timestamp_utc': '2023-07-12T06:16:00',
#    'timestamp_local': '2023-07-12T02:16:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 22.2,
#    'ts': 1689142620,
#    'timestamp_utc': '2023-07-12T06:17:00',
#    'timestamp_local': '2023-07-12T02:17:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 22.2,
#    'ts': 1689142680,
#    'timestamp_utc': '2023-07-12T06:18:00',
#    'timestamp_local': '2023-07-12T02:18:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 22.1,
#    'ts': 1689142740,
#    'timestamp_utc': '2023-07-12T06:19:00',
#    'timestamp_local': '2023-07-12T02:19:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 22.1,
#    'ts': 1689142800,
#    'timestamp_utc': '2023-07-12T06:20:00',
#    'timestamp_local': '2023-07-12T02:20:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 22.1,
#    'ts': 1689142860,
#    'timestamp_utc': '2023-07-12T06:21:00',
#    'timestamp_local': '2023-07-12T02:21:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 22,
#    'ts': 1689142920,
#    'timestamp_utc': '2023-07-12T06:22:00',
#    'timestamp_local': '2023-07-12T02:22:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 22,
#    'ts': 1689142980,
#    'timestamp_utc': '2023-07-12T06:23:00',
#    'timestamp_local': '2023-07-12T02:23:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21.9,
#    'ts': 1689143040,
#    'timestamp_utc': '2023-07-12T06:24:00',
#    'timestamp_local': '2023-07-12T02:24:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21.9,
#    'ts': 1689143100,
#    'timestamp_utc': '2023-07-12T06:25:00',
#    'timestamp_local': '2023-07-12T02:25:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21.9,
#    'ts': 1689143160,
#    'timestamp_utc': '2023-07-12T06:26:00',
#    'timestamp_local': '2023-07-12T02:26:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21.8,
#    'ts': 1689143220,
#    'timestamp_utc': '2023-07-12T06:27:00',
#    'timestamp_local': '2023-07-12T02:27:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21.8,
#    'ts': 1689143280,
#    'timestamp_utc': '2023-07-12T06:28:00',
#    'timestamp_local': '2023-07-12T02:28:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21.8,
#    'ts': 1689143340,
#    'timestamp_utc': '2023-07-12T06:29:00',
#    'timestamp_local': '2023-07-12T02:29:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21.7,
#    'ts': 1689143400,
#    'timestamp_utc': '2023-07-12T06:30:00',
#    'timestamp_local': '2023-07-12T02:30:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21.7,
#    'ts': 1689143460,
#    'timestamp_utc': '2023-07-12T06:31:00',
#    'timestamp_local': '2023-07-12T02:31:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21.6,
#    'ts': 1689143520,
#    'timestamp_utc': '2023-07-12T06:32:00',
#    'timestamp_local': '2023-07-12T02:32:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21.6,
#    'ts': 1689143580,
#    'timestamp_utc': '2023-07-12T06:33:00',
#    'timestamp_local': '2023-07-12T02:33:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21.6,
#    'ts': 1689143640,
#    'timestamp_utc': '2023-07-12T06:34:00',
#    'timestamp_local': '2023-07-12T02:34:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21.5,
#    'ts': 1689143700,
#    'timestamp_utc': '2023-07-12T06:35:00',
#    'timestamp_local': '2023-07-12T02:35:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21.5,
#    'ts': 1689143760,
#    'timestamp_utc': '2023-07-12T06:36:00',
#    'timestamp_local': '2023-07-12T02:36:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21.4,
#    'ts': 1689143820,
#    'timestamp_utc': '2023-07-12T06:37:00',
#    'timestamp_local': '2023-07-12T02:37:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21.4,
#    'ts': 1689143880,
#    'timestamp_utc': '2023-07-12T06:38:00',
#    'timestamp_local': '2023-07-12T02:38:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21.4,
#    'ts': 1689143940,
#    'timestamp_utc': '2023-07-12T06:39:00',
#    'timestamp_local': '2023-07-12T02:39:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21.3,
#    'ts': 1689144000,
#    'timestamp_utc': '2023-07-12T06:40:00',
#    'timestamp_local': '2023-07-12T02:40:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21.3,
#    'ts': 1689144060,
#    'timestamp_utc': '2023-07-12T06:41:00',
#    'timestamp_local': '2023-07-12T02:41:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21.2,
#    'ts': 1689144120,
#    'timestamp_utc': '2023-07-12T06:42:00',
#    'timestamp_local': '2023-07-12T02:42:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21.2,
#    'ts': 1689144180,
#    'timestamp_utc': '2023-07-12T06:43:00',
#    'timestamp_local': '2023-07-12T02:43:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21.2,
#    'ts': 1689144240,
#    'timestamp_utc': '2023-07-12T06:44:00',
#    'timestamp_local': '2023-07-12T02:44:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21.1,
#    'ts': 1689144300,
#    'timestamp_utc': '2023-07-12T06:45:00',
#    'timestamp_local': '2023-07-12T02:45:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21.1,
#    'ts': 1689144360,
#    'timestamp_utc': '2023-07-12T06:46:00',
#    'timestamp_local': '2023-07-12T02:46:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21,
#    'ts': 1689144420,
#    'timestamp_utc': '2023-07-12T06:47:00',
#    'timestamp_local': '2023-07-12T02:47:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21,
#    'ts': 1689144480,
#    'timestamp_utc': '2023-07-12T06:48:00',
#    'timestamp_local': '2023-07-12T02:48:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 21,
#    'ts': 1689144540,
#    'timestamp_utc': '2023-07-12T06:49:00',
#    'timestamp_local': '2023-07-12T02:49:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 20.9,
#    'ts': 1689144600,
#    'timestamp_utc': '2023-07-12T06:50:00',
#    'timestamp_local': '2023-07-12T02:50:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 20.9,
#    'ts': 1689144660,
#    'timestamp_utc': '2023-07-12T06:51:00',
#    'timestamp_local': '2023-07-12T02:51:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 20.8,
#    'ts': 1689144720,
#    'timestamp_utc': '2023-07-12T06:52:00',
#    'timestamp_local': '2023-07-12T02:52:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 20.8,
#    'ts': 1689144780,
#    'timestamp_utc': '2023-07-12T06:53:00',
#    'timestamp_local': '2023-07-12T02:53:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 20.8,
#    'ts': 1689144840,
#    'timestamp_utc': '2023-07-12T06:54:00',
#    'timestamp_local': '2023-07-12T02:54:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 20.7,
#    'ts': 1689144900,
#    'timestamp_utc': '2023-07-12T06:55:00',
#    'timestamp_local': '2023-07-12T02:55:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 20.7,
#    'ts': 1689144960,
#    'timestamp_utc': '2023-07-12T06:56:00',
#    'timestamp_local': '2023-07-12T02:56:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 20.6,
#    'ts': 1689145020,
#    'timestamp_utc': '2023-07-12T06:57:00',
#    'timestamp_local': '2023-07-12T02:57:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 20.6,
#    'ts': 1689145080,
#    'timestamp_utc': '2023-07-12T06:58:00',
#    'timestamp_local': '2023-07-12T02:58:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 20.6,
#    'ts': 1689145140,
#    'timestamp_utc': '2023-07-12T06:59:00',
#    'timestamp_local': '2023-07-12T02:59:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 20.5,
#    'ts': 1689145200,
#    'timestamp_utc': '2023-07-12T07:00:00',
#    'timestamp_local': '2023-07-12T03:00:00'},
#   {'precip': 0,
#    'snow': 0,
#    'temp': 20.5,
#    'ts': 1689145260,
#    'timestamp_utc': '2023-07-12T07:01:00',
#    'timestamp_local': '2023-07-12T03:01:00'}]}

# %%
data['data'][0]['app_temp']
# Out:
# 23.4

# %%
#!pip install snscrape
#!pip install transformers
#!pip install scipy

# %%
import snscrape.modules.twitter as sntweet
import pandas as pd

# %%
query = "(Covid) until:2021-01-01 since:2020-01-01"

# %%
tweets = []
limit = 10

# %%
for tweet in sntweet.TwitterSearchScraper(query).get_items():
#    print(vars(tweet))
#     print(tweet.rawContent)
#     print(tweet.date)
#     print(tweet.user.username)   
    if len(tweets) == limit:
        break
    else:
        tweets.append([tweet.date,tweet.user.username,tweet.rawContent])
# Out:
# Error retrieving https://twitter.com/i/api/graphql/7jT5GT59P8IFjgxwqnEdQw/SearchTimeline?variables=%7B%22rawQuery%22%3A%22%28Covid%29%20until%3A2021-01-01%20since%3A2020-01-01%22%2C%22count%22%3A20%2C%22product%22%3A%22Latest%22%2C%22withDownvotePerspective%22%3Afalse%2C%22withReactionsMetadata%22%3Afalse%2C%22withReactionsPerspective%22%3Afalse%7D&features=%7B%22rweb_lists_timeline_redesign_enabled%22%3Afalse%2C%22blue_business_profile_image_shape_enabled%22%3Afalse%2C%22responsive_web_graphql_exclude_directive_enabled%22%3Atrue%2C%22verified_phone_label_enabled%22%3Afalse%2C%22creator_subscriptions_tweet_preview_api_enabled%22%3Afalse%2C%22responsive_web_graphql_timeline_navigation_enabled%22%3Atrue%2C%22responsive_web_graphql_skip_user_profile_image_extensions_enabled%22%3Afalse%2C%22tweetypie_unmention_optimization_enabled%22%3Atrue%2C%22vibe_api_enabled%22%3Atrue%2C%22responsive_web_edit_tweet_api_enabled%22%3Atrue%2C%22graphql_is_translatable_rweb_tweet_is_translatable_enabled%22%3Atrue%2C%22view_counts_everywhere_api_enabled%22%3Atrue%2C%22longform_notetweets_consumption_enabled%22%3Atrue%2C%22tweet_awards_web_tipping_enabled%22%3Afalse%2C%22freedom_of_speech_not_reach_fetch_enabled%22%3Afalse%2C%22standardized_nudges_misinfo%22%3Atrue%2C%22tweet_with_visibility_results_prefer_gql_limited_actions_policy_enabled%22%3Afalse%2C%22interactive_text_enabled%22%3Atrue%2C%22responsive_web_text_conversations_enabled%22%3Afalse%2C%22longform_notetweets_rich_text_read_enabled%22%3Afalse%2C%22longform_notetweets_inline_media_enabled%22%3Afalse%2C%22responsive_web_enhance_cards_enabled%22%3Afalse%2C%22responsive_web_twitter_blue_verified_badge_is_enabled%22%3Atrue%7D: blocked (404)
# 4 requests to https://twitter.com/i/api/graphql/7jT5GT59P8IFjgxwqnEdQw/SearchTimeline?variables=%7B%22rawQuery%22%3A%22%28Covid%29%20until%3A2021-01-01%20since%3A2020-01-01%22%2C%22count%22%3A20%2C%22product%22%3A%22Latest%22%2C%22withDownvotePerspective%22%3Afalse%2C%22withReactionsMetadata%22%3Afalse%2C%22withReactionsPerspective%22%3Afalse%7D&features=%7B%22rweb_lists_timeline_redesign_enabled%22%3Afalse%2C%22blue_business_profile_image_shape_enabled%22%3Afalse%2C%22responsive_web_graphql_exclude_directive_enabled%22%3Atrue%2C%22verified_phone_label_enabled%22%3Afalse%2C%22creator_subscriptions_tweet_preview_api_enabled%22%3Afalse%2C%22responsive_web_graphql_timeline_navigation_enabled%22%3Atrue%2C%22responsive_web_graphql_skip_user_profile_image_extensions_enabled%22%3Afalse%2C%22tweetypie_unmention_optimization_enabled%22%3Atrue%2C%22vibe_api_enabled%22%3Atrue%2C%22responsive_web_edit_tweet_api_enabled%22%3Atrue%2C%22graphql_is_translatable_rweb_tweet_is_translatable_enabled%22%3Atrue%2C%22view_counts_everywhere_api_enabled%22%3Atrue%2C%22longform_notetweets_consumption_enabled%22%3Atrue%2C%22tweet_awards_web_tipping_enabled%22%3Afalse%2C%22freedom_of_speech_not_reach_fetch_enabled%22%3Afalse%2C%22standardized_nudges_misinfo%22%3Atrue%2C%22tweet_with_visibility_results_prefer_gql_limited_actions_policy_enabled%22%3Afalse%2C%22interactive_text_enabled%22%3Atrue%2C%22responsive_web_text_conversations_enabled%22%3Afalse%2C%22longform_notetweets_rich_text_read_enabled%22%3Afalse%2C%22longform_notetweets_inline_media_enabled%22%3Afalse%2C%22responsive_web_enhance_cards_enabled%22%3Afalse%2C%22responsive_web_twitter_blue_verified_badge_is_enabled%22%3Atrue%7D failed, giving up.
# Errors: blocked (404), blocked (404), blocked (404), blocked (404)
# ---------------------------------------------------------------------------
# ScraperException                          Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 for tweet in sntweet.TwitterSearchScraper(query).get_items():
#       2 #    print(vars(tweet))
#       3 #     print(tweet.rawContent)
#       4 #     print(tweet.date)
#       5 #     print(tweet.user.username)
#       6     if len(tweets) == limit:
#       7         break
#
# File ~\anaconda3\lib\site-packages\snscrape\modules\twitter.py:1763, in TwitterSearchScraper.get_items(self)
#    1760 params = {'variables': variables, 'features': features}
#    1761 paginationParams = {'variables': paginationVariables, 'features': features}
# -> 1763 for obj in self._iter_api_data('https://twitter.com/i/api/graphql/7jT5GT59P8IFjgxwqnEdQw/SearchTimeline', _TwitterAPIType.GRAPHQL, params, paginationParams, cursor = self._cursor, instructionsPath = ['data', 'search_by_raw_query', 'search_timeline', 'timeline', 'instructions']):
#    1764 	yield from self._graphql_timeline_instructions_to_tweets(obj['data']['search_by_raw_query']['search_timeline']['timeline']['instructions'])
#
# File ~\anaconda3\lib\site-packages\snscrape\modules\twitter.py:915, in _TwitterAPIScraper._iter_api_data(self, endpoint, apiType, params, paginationParams, cursor, direction, instructionsPath)
#     913 while True:
#     914 	_logger.info(f'Retrieving scroll page {cursor}')
# --> 915 	obj = self._get_api_data(endpoint, apiType, reqParams, instructionsPath = instructionsPath)
#     916 	yield obj
#     918 	# No data format test, just a hard and loud crash if anything's wrong :-)
#
# File ~\anaconda3\lib\site-packages\snscrape\modules\twitter.py:886, in _TwitterAPIScraper._get_api_data(self, endpoint, apiType, params, instructionsPath)
#     884 if apiType is _TwitterAPIType.GRAPHQL:
#     885 	params = urllib.parse.urlencode({k: json.dumps(v, separators = (',', ':')) for k, v in params.items()}, quote_via = urllib.parse.quote)
# --> 886 r = self._get(endpoint, params = params, headers = self._apiHeaders, responseOkCallback = functools.partial(self._check_api_response, apiType = apiType, instructionsPath = instructionsPath))
#     887 return r._snscrapeObj
#
# File ~\anaconda3\lib\site-packages\snscrape\base.py:275, in Scraper._get(self, *args, **kwargs)
#     274 def _get(self, *args, **kwargs):
# --> 275 	return self._request('GET', *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\snscrape\base.py:271, in Scraper._request(self, method, url, params, data, headers, timeout, responseOkCallback, allowRedirects, proxies)
#     269 	_logger.fatal(msg)
#     270 	_logger.fatal(f'Errors: {", ".join(errors)}')
# --> 271 	raise ScraperException(msg)
#     272 raise RuntimeError('Reached unreachable code')
#
# ScraperException: 4 requests to https://twitter.com/i/api/graphql/7jT5GT59P8IFjgxwqnEdQw/SearchTimeline?variables=%7B%22rawQuery%22%3A%22%28Covid%29%20until%3A2021-01-01%20since%3A2020-01-01%22%2C%22count%22%3A20%2C%22product%22%3A%22Latest%22%2C%22withDownvotePerspective%22%3Afalse%2C%22withReactionsMetadata%22%3Afalse%2C%22withReactionsPerspective%22%3Afalse%7D&features=%7B%22rweb_lists_timeline_redesign_enabled%22%3Afalse%2C%22blue_business_profile_image_shape_enabled%22%3Afalse%2C%22responsive_web_graphql_exclude_directive_enabled%22%3Atrue%2C%22verified_phone_label_enabled%22%3Afalse%2C%22creator_subscriptions_tweet_preview_api_enabled%22%3Afalse%2C%22responsive_web_graphql_timeline_navigation_enabled%22%3Atrue%2C%22responsive_web_graphql_skip_user_profile_image_extensions_enabled%22%3Afalse%2C%22tweetypie_unmention_optimization_enabled%22%3Atrue%2C%22vibe_api_enabled%22%3Atrue%2C%22responsive_web_edit_tweet_api_enabled%22%3Atrue%2C%22graphql_is_translatable_rweb_tweet_is_translatable_enabled%22%3Atrue%2C%22view_counts_everywhere_api_enabled%22%3Atrue%2C%22longform_notetweets_consumption_enabled%22%3Atrue%2C%22tweet_awards_web_tipping_enabled%22%3Afalse%2C%22freedom_of_speech_not_reach_fetch_enabled%22%3Afalse%2C%22standardized_nudges_misinfo%22%3Atrue%2C%22tweet_with_visibility_results_prefer_gql_limited_actions_policy_enabled%22%3Afalse%2C%22interactive_text_enabled%22%3Atrue%2C%22responsive_web_text_conversations_enabled%22%3Afalse%2C%22longform_notetweets_rich_text_read_enabled%22%3Afalse%2C%22longform_notetweets_inline_media_enabled%22%3Afalse%2C%22responsive_web_enhance_cards_enabled%22%3Afalse%2C%22responsive_web_twitter_blue_verified_badge_is_enabled%22%3Atrue%7D failed, giving up.

# %%
tweets

# %%
import requests

# %%
api_key = '7645c564ea36454c8e4e03c788702956'

# %%
url = f'https://api.weatherbit.io/v2.0/current?lat=35.7796&lon=-78.6382&key={api_key}&include=minutely'

# %%
response = requests.get(url)

# %%
data = response.json()

# %%
data['data'][0]['city_name']
# Out:
# 'Raleigh'

# %%
data['data'][0]['h_angle']
# Out:
# -90

# %%
import snscrape.modules.twitter as sntwitter

# %%
def get_tweets(query, max_tweets):
    tweets = []
    for i, tweet in enumerate(sntwitter.TwitterSearchScraper(query).get_items()):
        tweets.append(tweet)
        
        # Break the loop if the desired number of tweets is reached
        if i + 1 == max_tweets:
            break
    return tweets

# %%
#!pip install snscrape

# %%
import snscrape.modules.twitter as st

# %%
query = '(WorldCup) until:2023-01-10 since:2023-01-01'

# %%
tweet = []

for item in st.TwitterSearchScraper(query).get_items():
    if len(item) == 10:
        break
    else:
        tweet.append()
# Out:
# Error retrieving https://twitter.com/i/api/graphql/7jT5GT59P8IFjgxwqnEdQw/SearchTimeline?variables=%7B%22rawQuery%22%3A%22%28WorldCup%29%20until%3A2023-01-10%20since%3A2023-01-01%22%2C%22count%22%3A20%2C%22product%22%3A%22Latest%22%2C%22withDownvotePerspective%22%3Afalse%2C%22withReactionsMetadata%22%3Afalse%2C%22withReactionsPerspective%22%3Afalse%7D&features=%7B%22rweb_lists_timeline_redesign_enabled%22%3Afalse%2C%22blue_business_profile_image_shape_enabled%22%3Afalse%2C%22responsive_web_graphql_exclude_directive_enabled%22%3Atrue%2C%22verified_phone_label_enabled%22%3Afalse%2C%22creator_subscriptions_tweet_preview_api_enabled%22%3Afalse%2C%22responsive_web_graphql_timeline_navigation_enabled%22%3Atrue%2C%22responsive_web_graphql_skip_user_profile_image_extensions_enabled%22%3Afalse%2C%22tweetypie_unmention_optimization_enabled%22%3Atrue%2C%22vibe_api_enabled%22%3Atrue%2C%22responsive_web_edit_tweet_api_enabled%22%3Atrue%2C%22graphql_is_translatable_rweb_tweet_is_translatable_enabled%22%3Atrue%2C%22view_counts_everywhere_api_enabled%22%3Atrue%2C%22longform_notetweets_consumption_enabled%22%3Atrue%2C%22tweet_awards_web_tipping_enabled%22%3Afalse%2C%22freedom_of_speech_not_reach_fetch_enabled%22%3Afalse%2C%22standardized_nudges_misinfo%22%3Atrue%2C%22tweet_with_visibility_results_prefer_gql_limited_actions_policy_enabled%22%3Afalse%2C%22interactive_text_enabled%22%3Atrue%2C%22responsive_web_text_conversations_enabled%22%3Afalse%2C%22longform_notetweets_rich_text_read_enabled%22%3Afalse%2C%22longform_notetweets_inline_media_enabled%22%3Afalse%2C%22responsive_web_enhance_cards_enabled%22%3Afalse%2C%22responsive_web_twitter_blue_verified_badge_is_enabled%22%3Atrue%7D: blocked (404)
# 4 requests to https://twitter.com/i/api/graphql/7jT5GT59P8IFjgxwqnEdQw/SearchTimeline?variables=%7B%22rawQuery%22%3A%22%28WorldCup%29%20until%3A2023-01-10%20since%3A2023-01-01%22%2C%22count%22%3A20%2C%22product%22%3A%22Latest%22%2C%22withDownvotePerspective%22%3Afalse%2C%22withReactionsMetadata%22%3Afalse%2C%22withReactionsPerspective%22%3Afalse%7D&features=%7B%22rweb_lists_timeline_redesign_enabled%22%3Afalse%2C%22blue_business_profile_image_shape_enabled%22%3Afalse%2C%22responsive_web_graphql_exclude_directive_enabled%22%3Atrue%2C%22verified_phone_label_enabled%22%3Afalse%2C%22creator_subscriptions_tweet_preview_api_enabled%22%3Afalse%2C%22responsive_web_graphql_timeline_navigation_enabled%22%3Atrue%2C%22responsive_web_graphql_skip_user_profile_image_extensions_enabled%22%3Afalse%2C%22tweetypie_unmention_optimization_enabled%22%3Atrue%2C%22vibe_api_enabled%22%3Atrue%2C%22responsive_web_edit_tweet_api_enabled%22%3Atrue%2C%22graphql_is_translatable_rweb_tweet_is_translatable_enabled%22%3Atrue%2C%22view_counts_everywhere_api_enabled%22%3Atrue%2C%22longform_notetweets_consumption_enabled%22%3Atrue%2C%22tweet_awards_web_tipping_enabled%22%3Afalse%2C%22freedom_of_speech_not_reach_fetch_enabled%22%3Afalse%2C%22standardized_nudges_misinfo%22%3Atrue%2C%22tweet_with_visibility_results_prefer_gql_limited_actions_policy_enabled%22%3Afalse%2C%22interactive_text_enabled%22%3Atrue%2C%22responsive_web_text_conversations_enabled%22%3Afalse%2C%22longform_notetweets_rich_text_read_enabled%22%3Afalse%2C%22longform_notetweets_inline_media_enabled%22%3Afalse%2C%22responsive_web_enhance_cards_enabled%22%3Afalse%2C%22responsive_web_twitter_blue_verified_badge_is_enabled%22%3Atrue%7D failed, giving up.
# Errors: blocked (404), blocked (404), blocked (404), blocked (404)
# ---------------------------------------------------------------------------
# ScraperException                          Traceback (most recent call last)
# Input In [33], in <cell line: 3>()
#       1 tweet = []
# ----> 3 for item in st.TwitterSearchScraper(query).get_items():
#       4     if len(item) == 10:
#       5         break
#
# File ~\anaconda3\lib\site-packages\snscrape\modules\twitter.py:1763, in TwitterSearchScraper.get_items(self)
#    1760 params = {'variables': variables, 'features': features}
#    1761 paginationParams = {'variables': paginationVariables, 'features': features}
# -> 1763 for obj in self._iter_api_data('https://twitter.com/i/api/graphql/7jT5GT59P8IFjgxwqnEdQw/SearchTimeline', _TwitterAPIType.GRAPHQL, params, paginationParams, cursor = self._cursor, instructionsPath = ['data', 'search_by_raw_query', 'search_timeline', 'timeline', 'instructions']):
#    1764 	yield from self._graphql_timeline_instructions_to_tweets(obj['data']['search_by_raw_query']['search_timeline']['timeline']['instructions'])
#
# File ~\anaconda3\lib\site-packages\snscrape\modules\twitter.py:915, in _TwitterAPIScraper._iter_api_data(self, endpoint, apiType, params, paginationParams, cursor, direction, instructionsPath)
#     913 while True:
#     914 	_logger.info(f'Retrieving scroll page {cursor}')
# --> 915 	obj = self._get_api_data(endpoint, apiType, reqParams, instructionsPath = instructionsPath)
#     916 	yield obj
#     918 	# No data format test, just a hard and loud crash if anything's wrong :-)
#
# File ~\anaconda3\lib\site-packages\snscrape\modules\twitter.py:886, in _TwitterAPIScraper._get_api_data(self, endpoint, apiType, params, instructionsPath)
#     884 if apiType is _TwitterAPIType.GRAPHQL:
#     885 	params = urllib.parse.urlencode({k: json.dumps(v, separators = (',', ':')) for k, v in params.items()}, quote_via = urllib.parse.quote)
# --> 886 r = self._get(endpoint, params = params, headers = self._apiHeaders, responseOkCallback = functools.partial(self._check_api_response, apiType = apiType, instructionsPath = instructionsPath))
#     887 return r._snscrapeObj
#
# File ~\anaconda3\lib\site-packages\snscrape\base.py:275, in Scraper._get(self, *args, **kwargs)
#     274 def _get(self, *args, **kwargs):
# --> 275 	return self._request('GET', *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\snscrape\base.py:271, in Scraper._request(self, method, url, params, data, headers, timeout, responseOkCallback, allowRedirects, proxies)
#     269 	_logger.fatal(msg)
#     270 	_logger.fatal(f'Errors: {", ".join(errors)}')
# --> 271 	raise ScraperException(msg)
#     272 raise RuntimeError('Reached unreachable code')
#
# ScraperException: 4 requests to https://twitter.com/i/api/graphql/7jT5GT59P8IFjgxwqnEdQw/SearchTimeline?variables=%7B%22rawQuery%22%3A%22%28WorldCup%29%20until%3A2023-01-10%20since%3A2023-01-01%22%2C%22count%22%3A20%2C%22product%22%3A%22Latest%22%2C%22withDownvotePerspective%22%3Afalse%2C%22withReactionsMetadata%22%3Afalse%2C%22withReactionsPerspective%22%3Afalse%7D&features=%7B%22rweb_lists_timeline_redesign_enabled%22%3Afalse%2C%22blue_business_profile_image_shape_enabled%22%3Afalse%2C%22responsive_web_graphql_exclude_directive_enabled%22%3Atrue%2C%22verified_phone_label_enabled%22%3Afalse%2C%22creator_subscriptions_tweet_preview_api_enabled%22%3Afalse%2C%22responsive_web_graphql_timeline_navigation_enabled%22%3Atrue%2C%22responsive_web_graphql_skip_user_profile_image_extensions_enabled%22%3Afalse%2C%22tweetypie_unmention_optimization_enabled%22%3Atrue%2C%22vibe_api_enabled%22%3Atrue%2C%22responsive_web_edit_tweet_api_enabled%22%3Atrue%2C%22graphql_is_translatable_rweb_tweet_is_translatable_enabled%22%3Atrue%2C%22view_counts_everywhere_api_enabled%22%3Atrue%2C%22longform_notetweets_consumption_enabled%22%3Atrue%2C%22tweet_awards_web_tipping_enabled%22%3Afalse%2C%22freedom_of_speech_not_reach_fetch_enabled%22%3Afalse%2C%22standardized_nudges_misinfo%22%3Atrue%2C%22tweet_with_visibility_results_prefer_gql_limited_actions_policy_enabled%22%3Afalse%2C%22interactive_text_enabled%22%3Atrue%2C%22responsive_web_text_conversations_enabled%22%3Afalse%2C%22longform_notetweets_rich_text_read_enabled%22%3Afalse%2C%22longform_notetweets_inline_media_enabled%22%3Afalse%2C%22responsive_web_enhance_cards_enabled%22%3Afalse%2C%22responsive_web_twitter_blue_verified_badge_is_enabled%22%3Atrue%7D failed, giving up.

# %%
data['minutely']
# Out:
# [{'precip': 0,
#   'snow': 0,
#   'temp': 25,
#   'ts': 1689217380,
#   'timestamp_local': '2023-07-12T23:03:00',
#   'timestamp_utc': '2023-07-13T03:03:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25,
#   'ts': 1689217440,
#   'timestamp_local': '2023-07-12T23:04:00',
#   'timestamp_utc': '2023-07-13T03:04:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.1,
#   'ts': 1689217500,
#   'timestamp_local': '2023-07-12T23:05:00',
#   'timestamp_utc': '2023-07-13T03:05:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.1,
#   'ts': 1689217560,
#   'timestamp_local': '2023-07-12T23:06:00',
#   'timestamp_utc': '2023-07-13T03:06:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.1,
#   'ts': 1689217620,
#   'timestamp_local': '2023-07-12T23:07:00',
#   'timestamp_utc': '2023-07-13T03:07:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.1,
#   'ts': 1689217680,
#   'timestamp_local': '2023-07-12T23:08:00',
#   'timestamp_utc': '2023-07-13T03:08:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.2,
#   'ts': 1689217740,
#   'timestamp_local': '2023-07-12T23:09:00',
#   'timestamp_utc': '2023-07-13T03:09:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.2,
#   'ts': 1689217800,
#   'timestamp_local': '2023-07-12T23:10:00',
#   'timestamp_utc': '2023-07-13T03:10:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.2,
#   'ts': 1689217860,
#   'timestamp_local': '2023-07-12T23:11:00',
#   'timestamp_utc': '2023-07-13T03:11:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.2,
#   'ts': 1689217920,
#   'timestamp_local': '2023-07-12T23:12:00',
#   'timestamp_utc': '2023-07-13T03:12:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.2,
#   'ts': 1689217980,
#   'timestamp_local': '2023-07-12T23:13:00',
#   'timestamp_utc': '2023-07-13T03:13:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.3,
#   'ts': 1689218040,
#   'timestamp_local': '2023-07-12T23:14:00',
#   'timestamp_utc': '2023-07-13T03:14:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.3,
#   'ts': 1689218100,
#   'timestamp_local': '2023-07-12T23:15:00',
#   'timestamp_utc': '2023-07-13T03:15:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.3,
#   'ts': 1689218160,
#   'timestamp_local': '2023-07-12T23:16:00',
#   'timestamp_utc': '2023-07-13T03:16:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.3,
#   'ts': 1689218220,
#   'timestamp_local': '2023-07-12T23:17:00',
#   'timestamp_utc': '2023-07-13T03:17:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.4,
#   'ts': 1689218280,
#   'timestamp_local': '2023-07-12T23:18:00',
#   'timestamp_utc': '2023-07-13T03:18:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.4,
#   'ts': 1689218340,
#   'timestamp_local': '2023-07-12T23:19:00',
#   'timestamp_utc': '2023-07-13T03:19:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.4,
#   'ts': 1689218400,
#   'timestamp_local': '2023-07-12T23:20:00',
#   'timestamp_utc': '2023-07-13T03:20:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.4,
#   'ts': 1689218460,
#   'timestamp_local': '2023-07-12T23:21:00',
#   'timestamp_utc': '2023-07-13T03:21:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.5,
#   'ts': 1689218520,
#   'timestamp_local': '2023-07-12T23:22:00',
#   'timestamp_utc': '2023-07-13T03:22:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.5,
#   'ts': 1689218580,
#   'timestamp_local': '2023-07-12T23:23:00',
#   'timestamp_utc': '2023-07-13T03:23:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.5,
#   'ts': 1689218640,
#   'timestamp_local': '2023-07-12T23:24:00',
#   'timestamp_utc': '2023-07-13T03:24:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.5,
#   'ts': 1689218700,
#   'timestamp_local': '2023-07-12T23:25:00',
#   'timestamp_utc': '2023-07-13T03:25:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.6,
#   'ts': 1689218760,
#   'timestamp_local': '2023-07-12T23:26:00',
#   'timestamp_utc': '2023-07-13T03:26:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.6,
#   'ts': 1689218820,
#   'timestamp_local': '2023-07-12T23:27:00',
#   'timestamp_utc': '2023-07-13T03:27:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.6,
#   'ts': 1689218880,
#   'timestamp_local': '2023-07-12T23:28:00',
#   'timestamp_utc': '2023-07-13T03:28:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.6,
#   'ts': 1689218940,
#   'timestamp_local': '2023-07-12T23:29:00',
#   'timestamp_utc': '2023-07-13T03:29:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.6,
#   'ts': 1689219000,
#   'timestamp_local': '2023-07-12T23:30:00',
#   'timestamp_utc': '2023-07-13T03:30:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.7,
#   'ts': 1689219060,
#   'timestamp_local': '2023-07-12T23:31:00',
#   'timestamp_utc': '2023-07-13T03:31:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.7,
#   'ts': 1689219120,
#   'timestamp_local': '2023-07-12T23:32:00',
#   'timestamp_utc': '2023-07-13T03:32:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.7,
#   'ts': 1689219180,
#   'timestamp_local': '2023-07-12T23:33:00',
#   'timestamp_utc': '2023-07-13T03:33:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.7,
#   'ts': 1689219240,
#   'timestamp_local': '2023-07-12T23:34:00',
#   'timestamp_utc': '2023-07-13T03:34:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.8,
#   'ts': 1689219300,
#   'timestamp_local': '2023-07-12T23:35:00',
#   'timestamp_utc': '2023-07-13T03:35:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.8,
#   'ts': 1689219360,
#   'timestamp_local': '2023-07-12T23:36:00',
#   'timestamp_utc': '2023-07-13T03:36:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.8,
#   'ts': 1689219420,
#   'timestamp_local': '2023-07-12T23:37:00',
#   'timestamp_utc': '2023-07-13T03:37:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.8,
#   'ts': 1689219480,
#   'timestamp_local': '2023-07-12T23:38:00',
#   'timestamp_utc': '2023-07-13T03:38:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.9,
#   'ts': 1689219540,
#   'timestamp_local': '2023-07-12T23:39:00',
#   'timestamp_utc': '2023-07-13T03:39:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.9,
#   'ts': 1689219600,
#   'timestamp_local': '2023-07-12T23:40:00',
#   'timestamp_utc': '2023-07-13T03:40:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.9,
#   'ts': 1689219660,
#   'timestamp_local': '2023-07-12T23:41:00',
#   'timestamp_utc': '2023-07-13T03:41:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 25.9,
#   'ts': 1689219720,
#   'timestamp_local': '2023-07-12T23:42:00',
#   'timestamp_utc': '2023-07-13T03:42:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 26,
#   'ts': 1689219780,
#   'timestamp_local': '2023-07-12T23:43:00',
#   'timestamp_utc': '2023-07-13T03:43:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 26,
#   'ts': 1689219840,
#   'timestamp_local': '2023-07-12T23:44:00',
#   'timestamp_utc': '2023-07-13T03:44:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 26,
#   'ts': 1689219900,
#   'timestamp_local': '2023-07-12T23:45:00',
#   'timestamp_utc': '2023-07-13T03:45:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 26,
#   'ts': 1689219960,
#   'timestamp_local': '2023-07-12T23:46:00',
#   'timestamp_utc': '2023-07-13T03:46:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 26.1,
#   'ts': 1689220020,
#   'timestamp_local': '2023-07-12T23:47:00',
#   'timestamp_utc': '2023-07-13T03:47:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 26.1,
#   'ts': 1689220080,
#   'timestamp_local': '2023-07-12T23:48:00',
#   'timestamp_utc': '2023-07-13T03:48:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 26.1,
#   'ts': 1689220140,
#   'timestamp_local': '2023-07-12T23:49:00',
#   'timestamp_utc': '2023-07-13T03:49:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 26.1,
#   'ts': 1689220200,
#   'timestamp_local': '2023-07-12T23:50:00',
#   'timestamp_utc': '2023-07-13T03:50:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 26.1,
#   'ts': 1689220260,
#   'timestamp_local': '2023-07-12T23:51:00',
#   'timestamp_utc': '2023-07-13T03:51:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 26.2,
#   'ts': 1689220320,
#   'timestamp_local': '2023-07-12T23:52:00',
#   'timestamp_utc': '2023-07-13T03:52:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 26.2,
#   'ts': 1689220380,
#   'timestamp_local': '2023-07-12T23:53:00',
#   'timestamp_utc': '2023-07-13T03:53:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 26.2,
#   'ts': 1689220440,
#   'timestamp_local': '2023-07-12T23:54:00',
#   'timestamp_utc': '2023-07-13T03:54:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 26.2,
#   'ts': 1689220500,
#   'timestamp_local': '2023-07-12T23:55:00',
#   'timestamp_utc': '2023-07-13T03:55:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 26.3,
#   'ts': 1689220560,
#   'timestamp_local': '2023-07-12T23:56:00',
#   'timestamp_utc': '2023-07-13T03:56:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 26.3,
#   'ts': 1689220620,
#   'timestamp_local': '2023-07-12T23:57:00',
#   'timestamp_utc': '2023-07-13T03:57:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 26.3,
#   'ts': 1689220680,
#   'timestamp_local': '2023-07-12T23:58:00',
#   'timestamp_utc': '2023-07-13T03:58:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 26.3,
#   'ts': 1689220740,
#   'timestamp_local': '2023-07-12T23:59:00',
#   'timestamp_utc': '2023-07-13T03:59:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 26.4,
#   'ts': 1689220800,
#   'timestamp_local': '2023-07-13T00:00:00',
#   'timestamp_utc': '2023-07-13T04:00:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 26.3,
#   'ts': 1689220860,
#   'timestamp_local': '2023-07-13T00:01:00',
#   'timestamp_utc': '2023-07-13T04:01:00'},
#  {'precip': 0,
#   'snow': 0,
#   'temp': 26.3,
#   'ts': 1689220920,
#   'timestamp_local': '2023-07-13T00:02:00',
#   'timestamp_utc': '2023-07-13T04:02:00'}]

# %%
precip = []
snow = []
temp = []
ts = []

for item in range(0,5):
    z = data['minutely'][item]
    precip.append(z['precip'])
    temp.append(z['temp'])
    ts.append(z['ts'])

# %%
import pandas

# %%
df = pandas.DataFrame({'precip':precip, 'temp':temp, 'ts':ts})

# %%
df.to_csv('Weather_Sheet.csv')

# %%
import os
os.getcwd()
# Out:
# 'E:\\Besant Python'
